# %%
# !pip install mne
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 56.2 MB/s eta 0:00:00
# ...

# %%
import os
import mne
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Importing The Dataset**

# %%
X = np.empty([256,15])
Y = []

# %%
alcoholfiles = os.listdir('/content/drive/MyDrive/Alcoholism Research/Alcoholic')
alcoholfiles
# Out:
# ['alcohol1.csv',
#  'alcohol2.csv',
#  'alcohol3.csv',
#  'alcohol4.csv',
#  'alcohol5.csv',
#  'alcohol6.csv',
#  'alcohol7.csv',
#  'alcohol8.csv',
#  'alcohol9.csv',
#  'alcohol10.csv',
#  'alcohol11.csv',
#  'alcohol12.csv',
#  'alcohol13.csv',
#  'alcohol14.csv',
#  'alcohol15.csv',
#  'alcohol16.csv',
#  'alcohol17.csv',
#  'alcohol18.csv',
#  'alcohol19.csv',
#  'alcohol20.csv',
#  'alcohol21.csv',
#  'alcohol22.csv',
#  'alcohol23.csv',
#  'alcohol24.csv',
#  'alcohol25.csv',
#  'alcohol26.csv',
#  'alcohol27.csv',
#  'alcohol28.csv',
#  'alcohol29.csv',
#  'alcohol30.csv',
#  'alcohol31.csv',
#  'alcohol32.csv',
#  'alcohol33.csv',
#  'alcohol34.csv',
#  'alcohol35.csv',
#  'alcohol36.csv',
#  'alcohol37.csv',
#  'alcohol38.csv',
#  'alcohol39.csv',
#  'alcohol40.csv']

# %%
for f in alcoholfiles:
  path = os.path.join('/content/drive/MyDrive/Alcoholism Research/Alcoholic',f)
  df = pd.read_csv(path)
  df = df[['FP2','F8','O2','FP1','F7','O1','F4','C4','P4','F3','C3','P3','FZ','CZ','PZ']]
  print(f)
  #df = df.drop(['Unnamed: 0'],axis=1)
  df_stats = df.describe()
  df_stats = df_stats.transpose()

  def norm(X):
    return X-df_stats['mean']/df_stats['std']

  df = norm(df)
  X = np.concatenate((X,df.values),axis=0)

  for i in range(0,len(df.values)):
      Y.append(1)
# Out:
# alcohol1.csv
# alcohol2.csv
# alcohol3.csv
# alcohol4.csv
# alcohol5.csv
# alcohol6.csv
# alcohol7.csv
# alcohol8.csv
# alcohol9.csv
# alcohol10.csv
# alcohol11.csv
# alcohol12.csv
# alcohol13.csv
# alcohol14.csv
# alcohol15.csv
# alcohol16.csv
# alcohol17.csv
# alcohol18.csv
# alcohol19.csv
# alcohol20.csv
# alcohol21.csv
# alcohol22.csv
# alcohol23.csv
# alcohol24.csv
# alcohol25.csv
# alcohol26.csv
# alcohol27.csv
# alcohol28.csv
# alcohol29.csv
# alcohol30.csv
# alcohol31.csv
# alcohol32.csv
# alcohol33.csv
# alcohol34.csv
# alcohol35.csv
# alcohol36.csv
# alcohol37.csv
# alcohol38.csv
# alcohol39.csv
# alcohol40.csv

# %%
X.shape
# Out:
# (10496, 15)

# %%
X = X[256:]

# %%
X.shape
# Out:
# (10240, 15)

# %%
controlledfiles = os.listdir('/content/drive/MyDrive/Alcoholism Research/Controlled')

# %%
controlledfiles = controlledfiles[:20]
for f in controlledfiles:
  path = os.path.join('/content/drive/MyDrive/Alcoholism Research/Controlled',f)
  df = pd.read_csv(path)
  df = df[['FP2','F8','O2','FP1','F7','O1','F4','C4','P4','F3','C3','P3','FZ','CZ','PZ']]
  print(f)
  #df = df.drop(['Unnamed: 0'],axis=1)
  df_stats = df.describe()
  df_stats = df_stats.transpose()

  def norm(X):
    return X-df_stats['mean']/df_stats['std']

  df = norm(df)
  X = np.concatenate((X,df.values),axis=0)

  for i in range(0,len(df.values)):
      Y.append(0)
# Out:
# controlled1.csv
# controlled2.csv
# controlled3.csv
# controlled4.csv
# controlled5.csv
# controlled6.csv
# controlled7.csv
# controlled8.csv
# controlled9.csv
# controlled10.csv
# controlled11.csv
# controlled12.csv
# controlled13.csv
# controlled14.csv
# controlled15.csv
# controlled16.csv
# controlled17.csv
# controlled18.csv
# controlled19.csv
# controlled20.csv

# %%
healthyfiles = os.listdir('/content/drive/MyDrive/Alcoholism Research/Healthy')
healthyfiles
# Out:
# ['h01.edf',
#  'h02.edf',
#  'h03.edf',
#  'h04.edf',
#  'h05.edf',
#  'h06.edf',
#  'h07.edf',
#  'h08.edf',
#  'h09.edf',
#  'h10.edf',
#  'h11.edf',
#  'h12.edf',
#  'h13.edf',
#  'h14.edf']

# %%
healthyfiles = healthyfiles[:5]
for f in healthyfiles:
  path = os.path.join('/content/drive/MyDrive/Alcoholism Research/Healthy',f)
  raw = mne.io.read_raw_edf(path)
  df = raw.to_data_frame()
  df = df[['Fp2','F8','O2','Fp1','F7','O1','F4','C4','P4','F3','C3','P3','Fz','Cz','Pz']]
 
  print(f)
  df_stats = df.describe()
  df_stats = df_stats.transpose()

  def norm(X):
    return X-df_stats['mean']/df_stats['std']

  df = norm(df)
  df = df.iloc[:750]
  X = np.concatenate((X,df.values),axis=0)

  for i in range(0,len(df.values)):
      Y.append(0)
# Out:
# Extracting EDF parameters from /content/drive/MyDrive/Alcoholism Research/Healthy/h01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# h01.edf
# Extracting EDF parameters from /content/drive/MyDrive/Alcoholism Research/Healthy/h02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# h02.edf
# Extracting EDF parameters from /content/drive/MyDrive/Alcoholism Research/Healthy/h03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# h03.edf
# Extracting EDF parameters from /content/drive/MyDrive/Alcoholism Research/Healthy/h04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# h04.edf
# Extracting EDF parameters from /content/drive/MyDrive/Alcoholism Research/Healthy/h05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# h05.edf

# %%
X.shape
# Out:
# (19110, 15)

# %%
schizophrenicfiles = os.listdir('/content/drive/MyDrive/Alcoholism Research/Schizophrenic')
schizophrenicfiles
# Out:
# ['s01.edf',
#  's02.edf',
#  's03.edf',
#  's04.edf',
#  's05.edf',
#  's06.edf',
#  's07.edf',
#  's08.edf',
#  's09.edf',
#  's10.edf',
#  's11.edf',
#  's12.edf',
#  's13.edf',
#  's14.edf']

# %%
for f in schizophrenicfiles:
  path = os.path.join('/content/drive/MyDrive/Alcoholism Research/Schizophrenic',f)
  raw = mne.io.read_raw_edf(path)
  df = raw.to_data_frame()
  df = df[['Fp2','F8','O2','Fp1','F7','O1','F4','C4','P4','F3','C3','P3','Fz','Cz','Pz']]
  
  print(f)
  df_stats = df.describe()
  df_stats = df_stats.transpose()

  def norm(X):
    return X-df_stats['mean']/df_stats['std']

  df = norm(df)
  df = df.iloc[:750]
  X = np.concatenate((X,df.values),axis=0)

  for i in range(0,len(df.values)):
      Y.append(2)
# Out:
# Extracting EDF parameters from /content/drive/MyDrive/Alcoholism Research/Schizophrenic/s01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# s01.edf
# Extracting EDF parameters from /content/drive/MyDrive/Alcoholism Research/Schizophrenic/s02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# s02.edf
# Extracting EDF parameters from /content/drive/MyDrive/Alcoholism Research/Schizophrenic/s03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# s03.edf
# Extracting EDF parameters from /content/drive/MyDrive/Alcoholism Research/Schizophrenic/s04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# s04.edf
# Extracting EDF parameters from /content/drive/MyDrive/Alcoholism Research/Schizophrenic/s05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# s05.edf
# ...

# %%
X.shape
# Out:
# (29610, 15)

# %%
Y = np.array(Y)

# %%
Y.shape
# Out:
# (29610,)

# %%
Y
# Out:
# array([1, 1, 1, ..., 2, 2, 2])

# %% [markdown]
# # **Loading Alcoholic Pre-Trained Model**

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.models import clone_model

# %%
model1 = load_model('/content/drive/MyDrive/Alcoholism Research/alcoholANN1.h5')

# %%
model1_clone = clone_model(model1)

# %%
model1_clone.set_weights(model1.get_weights())

# %%
model1_clone.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_23 (Dense)            (None, 7)                 112
#
#  dense_24 (Dense)            (None, 8)                 64
#
#  dense_25 (Dense)            (None, 1)                 9
#
# ...
# Total params: 185
# Trainable params: 185
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # **Train Test Split**

# %%
from tensorflow.keras.utils import to_categorical

Y = to_categorical(Y)
Y
# Out:
# array([[0., 1., 0.],
#        [0., 1., 0.],
#        [0., 1., 0.],
#        ...,
#        [0., 0., 1.],
#        [0., 0., 1.],
#        [0., 0., 1.]], dtype=float32)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.1,random_state=500)

# %%
X_train.shape
# Out:
# (26649, 15)

# %%
Y_train.shape
# Out:
# (26649, 3)

# %%
X_test.shape
# Out:
# (2961, 15)

# %%
Y_test.shape
# Out:
# (2961, 3)

# %% [markdown]
# # **Creating a New Model Using Transfer Learning**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(1200,input_shape=[15],activation='relu'))
model.add(Dense(1200,activation='tanh'))
model.add(Dense(1200,activation='relu'))
model.add(Dense(1200,activation='tanh'))

model.add(Dense(3,activation='softmax'))

model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

earlystop = EarlyStopping(monitor='val_loss',patience=5)

# %%
model.fit(X_train,Y_train,validation_data=(X_test,Y_test),epochs=100,callbacks=[earlystop])
# Out:
# Epoch 1/100
# 833/833 [==============================] - 5s 4ms/step - loss: 0.5670 - accuracy: 0.7670 - val_loss: 0.4394 - val_accuracy: 0.8078
# Epoch 2/100
# 833/833 [==============================] - 3s 4ms/step - loss: 0.3784 - accuracy: 0.8422 - val_loss: 0.3353 - val_accuracy: 0.8615
# Epoch 3/100
# 833/833 [==============================] - 4s 5ms/step - loss: 0.3028 - accuracy: 0.8807 - val_loss: 0.3272 - val_accuracy: 0.8707
# Epoch 5/100
# 833/833 [==============================] - 3s 4ms/step - loss: 0.2807 - accuracy: 0.8882 - val_loss: 0.2935 - val_accuracy: 0.8808
# Epoch 6/100
# 833/833 [==============================] - 3s 4ms/step - loss: 0.2570 - accuracy: 0.9007 - val_loss: 0.2711 - val_accuracy: 0.8956
# Epoch 7/100
# 833/833 [==============================] - 5s 6ms/step - loss: 0.2388 - accuracy: 0.9079 - val_loss: 0.2576 - val_accuracy: 0.9034
# Epoch 8/100
# ...

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot()
# Out:
# <Axes: >

# %%
Y_pred = np.round(model.predict(X_test))
# Out:
# 93/93 [==============================] - 0s 2ms/step

# %%
from sklearn.metrics import classification_report

print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89       874
#            1       0.97      0.92      0.94      1066
#            2       0.92      0.92      0.92      1021
#
#    micro avg       0.92      0.92      0.92      2961
#    macro avg       0.92      0.92      0.92      2961
# weighted avg       0.92      0.92      0.92      2961
#  samples avg       0.92      0.92      0.92      2961
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # **Testing On Out Of Sample Data**

# %%
raw = mne.io.read_raw_edf('/content/drive/MyDrive/Alcoholism Research/Healthy/h14.edf')
h01 = raw.to_data_frame()
h01 = h01[['Fp2','F8','O2','Fp1','F7','O1','F4','C4','P4','F3','C3','P3','Fz','Cz','Pz']]
h01
#h01 = h01.transpose()

h01_stats = h01.describe()
h01_stats = h01_stats.transpose()

def normh01(X):
  return (X-h01_stats['mean'])/h01_stats['std']

h01 = normh01(h01)

X1 = h01.values
Y1 = []
for i in range(0,len(h01.values)):
      Y1.append(0)
# Out:
# Extracting EDF parameters from /content/drive/MyDrive/Alcoholism Research/Healthy/h14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...

# %%
Y1_pred = np.round(model.predict(X1))
# Out:
# 6758/6758 [==============================] - 11s 2ms/step

# %%
Y1_pred.shape
# Out:
# (216250, 3)

# %%
count0 = 0
count1 = 0
count2 = 0

for i in range(0,216250):
  if(Y1_pred[i][0] == 1):
   count0 = count0 + 1
  if(Y1_pred[i][1] == 1):
    count1 = count1 + 1
  if(Y1_pred[i][2] == 1):
    count2 = count2 + 1

# %%
print(count0)
print(count1)
print(count2)
# Out:
# 16825
# 39
# 199321

# %%
raw = mne.io.read_raw_edf('/content/drive/MyDrive/Alcoholism Research/Schizophrenic/s01.edf')
s01 = raw.to_data_frame()
s01 = s01[['Fp2','F8','O2','Fp1','F7','O1','F4','C4','P4','F3','C3','P3','Fz','Cz','Pz']]
s01
#h01 = h01.transpose()

s01_stats = s01.describe()
s01_stats = s01_stats.transpose()

def norms01(X):
  return (X-s01_stats['mean'])/s01_stats['std']

s01 = norms01(s01)
X2 = s01.values
Y2 = []
for i in range(0,len(s01.values)):
      Y2.append(2)
# Out:
# Extracting EDF parameters from /content/drive/MyDrive/Alcoholism Research/Schizophrenic/s01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...

# %%
Y2_pred = np.round(model.predict(X2))
# Out:
# 6602/6602 [==============================] - 12s 2ms/step

# %%
Y2_pred.shape
# Out:
# (211250, 3)

# %%
count0 = 0
count1 = 0
count2 = 0

for i in range(0,211250):
  if(Y2_pred[i][0] == 1):
   count0 = count0 + 1
  if(Y2_pred[i][1] == 1):
    count1 = count1 + 1
  if(Y2_pred[i][2] == 1):
    count2 = count2 + 1

# %%
print(count0)
print(count1)
print(count2)
# Out:
# 48925
# 254
# 161861

# %%
path = os.path.join('/content/drive/MyDrive/Alcoholism Research/Controlled','controlled30.csv')
df = pd.read_csv(path)
df = df[['FP2','F8','O2','FP1','F7','O1','F4','C4','P4','F3','C3','P3','FZ','CZ','PZ']]
#print(f)
#df = df.drop(['Unnamed: 0'],axis=1)
df_stats = df.describe()
df_stats = df_stats.transpose()

def norm(X):
  return X-df_stats['mean']/df_stats['std']

df = norm(df)
X3 = df.values
Y3 = []
for i in range(0,len(df.values)):
    Y3.append(0)

# %%
Y3_pred = np.round(model.predict(X3))
# Out:
# 8/8 [==============================] - 0s 2ms/step

# %%
Y3_pred.shape
# Out:
# (256, 3)

# %%
count0 = 0
count1 = 0
count2 = 0

for i in range(0,256):
  if(Y3_pred[i][0] == 1):
   count0 = count0 + 1
  if(Y3_pred[i][1] == 1):
    count1 = count1 + 1
  if(Y3_pred[i][2] == 1):
    count2 = count2 + 1

# %%
print(count0)
print(count1)
print(count2)
# Out:
# 200
# 46
# 8

# %%
path = os.path.join('/content/drive/MyDrive/Alcoholism Research/Alcoholic','alcohol30.csv')
df = pd.read_csv(path)
df = df[['FP2','F8','O2','FP1','F7','O1','F4','C4','P4','F3','C3','P3','FZ','CZ','PZ']]
#print(f)
#df = df.drop(['Unnamed: 0'],axis=1)
df_stats = df.describe()
df_stats = df_stats.transpose()

def norm(X):
  return X-df_stats['mean']/df_stats['std']

df = norm(df)
X4 = df.values
Y4 = []
for i in range(0,len(df.values)):
    Y4.append(1)

# %%
Y4_pred = np.round(model.predict(X4))
# Out:
# 8/8 [==============================] - 0s 2ms/step

# %%
Y4_pred.shape
# Out:
# (256, 3)

# %%
count0 = 0
count1 = 0
count2 = 0

for i in range(0,256):
  if(Y4_pred[i][0] == 1):
   count0 = count0 + 1
  if(Y4_pred[i][1] == 1):
    count1 = count1 + 1
  if(Y4_pred[i][2] == 1):
    count2 = count2 + 1

# %%
print(count0)
print(count1)
print(count2)
# Out:
# 2
# 250
# 3

# %% [markdown]
# # **Saving Current Model**

# %%
model.save('/content/drive/MyDrive/Alcoholism Research/CompoundANN1.h5')
